# %%
# Read pdf pages 125:135 and convert them into text
library(pdftools)
readpage<- pdf_convert('M:\\Imarticus\\ProjectR\\Text mining\\Datafiles\\Teaching sports.pdf',
                      pages=125:135)
text<- tesseract::ocr(readpage)
# Out:
# Converting page 125 to Teaching sports_125.png... done!
# Converting page 126 to Teaching sports_126.png... done!
# Converting page 127 to Teaching sports_127.png... done!
# Converting page 128 to Teaching sports_128.png... done!
# Converting page 129 to Teaching sports_129.png... done!
# Converting page 130 to Teaching sports_130.png... done!
# Converting page 131 to Teaching sports_131.png... done!
# Converting page 132 to Teaching sports_132.png... done!
# Converting page 133 to Teaching sports_133.png... done!
# Converting page 134 to Teaching sports_134.png... done!
# Converting page 135 to Teaching sports_135.png... done!

# %%
library("tm")
library("SnowballC")
library("wordcloud")
library("RColorBrewer")
library(tidytext)
library(dplyr)
data(stop_words)
# Out:
# Loading required package: NLP
#
# Attaching package: 'NLP'
#
# The following object is masked from 'package:ggplot2':
#
#     annotate
#
# Loading required package: RColorBrewer
#
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# clean text using stringr
library(stringr)
# Remove alphanumeric characters & punctuation
textnew<- str_replace_all(text, "[[:punct:]]", " ")
textnew<-str_replace_all(textnew, "[^[:alnum:]]", " ")

# %%
var <- Corpus(VectorSource(textnew))

# Convert the text to lower case
var <- tm_map(var, content_transformer(tolower))
# Remove numbers
var <- tm_map(var, removeNumbers)
# Remove english common stopwords
var <- tm_map(var, removeWords, stopwords("english"))
# Remove your own stop word
var <- tm_map(var, removeWords,c("ofthe","tothe","tomake" ,"atthe","forthe","bal","ine",
               "fot"))
# Eliminate extra white spaces
var <- tm_map(var, stripWhitespace)
# Out:
# Warning message in tm_map.SimpleCorpus(var, content_transformer(tolower)):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(var, removeNumbers):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(var, removeWords, stopwords("english")):
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(var, removeWords, c("ofthe", "tothe", "tomake", :
# "transformation drops documents"Warning message in tm_map.SimpleCorpus(var, stripWhitespace):
# "transformation drops documents"

# %%
dtm <- TermDocumentMatrix(var)
matrix <- as.matrix(dtm)
sorted_sum <- sort(rowSums(matrix),decreasing=TRUE)
table <- data.frame(word = names(sorted_sum ),freq=sorted_sum )
table <- table %>% anti_join(stop_words)
# Out:
# Joining, by = "word"
# Warning message:
# "Column `word` joining factor and character vector, coercing into character vector"

# %%
#top 50 words
top50_words<-head(table,50)
top50_words
# Out:
#    word         freq
# 1  ball         28
# 2  students     26
# 3  shot         18
# 4  batter       16
# 5  post         13
# 6  equipment    10
# 7  foot         10
# 8  team          9
# 9  distance      9
# 10 putting       9
# 11 game          8
# 12 activity      8
# 13 markers       7
# 14 run           7
# 15 action        7
# 16 ground        6
# 17 square        6
# 18 objectives    6
# 19 teaching      6
# 20 line          6
# 21 stage         6
# 22 putter        6
# 23 bat           5
# 24 rounders      5
# 25 stand         5
# 26 release       5
# 27 aim           4
# 28 fielding      4
# 29 measurements  4
# 30 pitch         4
# 31 players       4
# 32 running       4
# 33 score         4
# 34 change        4
# 35 easier        4
# 36 minutes       4
# 37 runners       4
# 38 teacher       4
# 39 throwing      4
# 40 time          4
# 41 activities    4
# 42 measured      4
# 43 practise      4
# 44 standing      4
# 45 weight        4
# 46 mark          4
# 47 marker        4
# 48 batting       3
# 49 bowler        3
# 50 hand          3

# %%
#word frequency plot
library(ggplot2)
ggplot(top50_words, aes(x= reorder(word, -freq), y = freq)) +
  geom_bar(stat = "identity")+ 
 theme(axis.text.x=element_text(angle=90, hjust=1))
# Out:
# plot without title

# %%
#wordcloud
set.seed(1234)
wordcloud(words = table$word, freq = table$freq, min.freq = 1,
          max.words=100, random.order=FALSE, 
          colors=brewer.pal(8, "Paired"))
# Out:
# plot without title
